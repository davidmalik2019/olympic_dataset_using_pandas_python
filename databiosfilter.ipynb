# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('./data/latest_row.csv')
new=df[df['born_country'].str.contains('CUB')]
print(new)
new.to_csv('./data/databeforeplot_row.csv', index=False , na_rep='N/A')
# Out:
#       athlete_id             name   born_date              born_city  \
# 29          1487   Rolando Arrojo  1965-07-18  San Juan de los Yeras
# 30          1489   José Contreras  1971-12-06           Las Martinas
# 31          1500  Pedro Luis Lazo  1973-04-15          Pinar del Río
# 32          1511    Ormari Romero  1968-02-22       Santiago de Cuba
# 33          1512    Antonio Scull  1965-09-10  San Miguel del Padrón
# ...          ...              ...         ...                    ...
# 8038      135631    Rafael Capote  1987-10-05     La Habana (Havana)
# 8139      136134  Yasmani Copello  1987-04-15     La Habana (Havana)
# 8375      141286      Yoandy Leal  1988-08-31     La Habana (Havana)
# 8560      146039   Daymaro Salina  1987-09-01               Artemisa
# 8566      146049  Victor Iturriza  1990-05-22     La Habana (Havana)
#
#               born_region born_country           NOC  height_cm  weight_kg  \
# 29            Villa Clara          CUB          Cuba      193.0      100.0
# 30          Pinar del Río          CUB          Cuba      191.0      107.0
# 31          Pinar del Río          CUB          Cuba      192.0      107.0
# 32       Santiago de Cuba          CUB          Cuba      196.0       86.0
# 33    Ciudad de La Habana          CUB          Cuba      195.0       96.0
# ...                   ...          ...           ...        ...        ...
# 8038  Ciudad de La Habana          CUB         Qatar      196.0      109.0
# 8139  Ciudad de La Habana          CUB  Cuba Türkiye      191.0       85.0
# 8375  Ciudad de La Habana          CUB        Brazil      201.0      104.0
# 8560             Artemisa          CUB      Portugal      200.0      118.0
# 8566  Ciudad de La Habana          CUB      Portugal      194.0      120.0
#
#      died_date
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# ...        ...
# 8038       NaN
# 8139       NaN
# 8375       NaN
# 8560       NaN
# 8566       NaN
#
# [90 rows x 10 columns]
